# %%
import pandas as pd

# %%
df = pd.read_pickle('./Data/Rawdata/debug_data.pkl')
df.head()
# Out:
#     borough    bin_# house_#      street_name      job_# job_doc._# job_type  \
# 0  BROOKLYN  3127307     814    DITMAS AVENUE  301068644          1       A3
# 1    QUEENS  4295034  156-27       101 STREET  402062520          1       A1
# 2  BROOKLYN  3009015     209      18TH STREET  320934487          1       A1
# 3    QUEENS  4181643   84-05   FOREST PARKWAY  401838614          1       A1
# 4  BROOKLYN  3002691      36  SCHERMERHORN ST  321197735          1       A1
#
#   self_cert  block    lot  ... owner’s_house_state owner’s_house_zip_code  \
# 0       NaN  05402  00006  ...                 NaN                   <NA>
# 1       NaN  14162  00047  ...                 NaN                   <NA>
# 2         N  00631  00065  ...                 NaN                   <NA>
# 3         Y  08858  00001  ...                 NaN                   <NA>
# 4         N  00270  00044  ...                 NaN                   <NA>
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39523 entries, 0 to 779
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   borough                           39523 non-null  category
#  1   bin_#                             39523 non-null  string
#  2   house_#                           39523 non-null  string
#  3   street_name                       39523 non-null  string
#  4   job_#                             39523 non-null  string
#  5   job_doc._#                        39523 non-null  category
#  6   job_type                          39523 non-null  category
#  7   self_cert                         26246 non-null  category
#  8   block                             39523 non-null  string
#  9   lot                               39523 non-null  string
#  10  community_board                   39501 non-null  string
# ...
