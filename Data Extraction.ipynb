# %%
# Impost nessary libraries
import pandas as pd

# Set display options to show all rows and columns without truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Import DOB data
df = pd.read_csv('./Data/Rawdata/DOB_Permit_Issuance.csv')
df.shape
# Out:
# C:\Users\email\AppData\Local\Temp\ipykernel_33324\3828342685.py:2: DtypeWarning: Columns (1,8,9,10,15,31,33,36,47,48,49,50,51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data/Rawdata/DOB_Permit_Issuance.csv')
# (3938890, 60)

# %%
# Check first 5 rows of data
df.head()
# Out:
#          BOROUGH    Bin # House #       Street Name        Job #  Job doc. #  \
# 0      MANHATTAN  1088749       1       MADISON AVE  141008987.0         1.0
# 1  STATEN ISLAND  5076937      87     BOYLAN STREET  540218539.0         1.0
# 2  STATEN ISLAND  5001506     217  LAFAYETTE AVENUE  540218575.0         1.0
# 3  STATEN ISLAND  5067021     170    OAKDALE STREET  540218600.0         1.0
# 4  STATEN ISLAND  5058036     273         10 STREET  540218628.0         1.0
#
#   Job Type Self_Cert   Block   Lot Community Board  Zip Code  Bldg Type  \
# 0       A3         Y   853.0   2.0             105   10010.0        2.0
# 1       A2         Y  5687.0  66.0             503   10312.0        1.0
# 2       A2         Y    64.0  22.0             501   10301.0        1.0
# 3       A2         Y  5260.0   1.0             503   10308.0        1.0
# 4       A2         Y  4242.0  45.0             502   10306.0        1.0
#
#   Residential Special District 1 Special District 2 Work Type Permit Status  \
# 0         NaN                NaN                NaN        EQ        ISSUED
# 1         YES                SRD                NaN        OT        ISSUED
# 2         YES                 HS                NaN        OT        ISSUED
# 3         YES                SRD                NaN        OT        ISSUED
# 4         YES                NaN                NaN        OT        ISSUED
#
#   Filing Status Permit Type  Permit Sequence # Permit Subtype Oil Gas  \
# 0       INITIAL          EQ                1.0             OT     NaN
# 1       INITIAL          EW                1.0             OT     NaN
# 2       INITIAL          EW                1.0             OT     NaN
# 3       INITIAL          EW                1.0             OT     NaN
# 4       INITIAL          EW                1.0             OT     NaN
#
#         Site Fill Filing Date Issuance Date Expiration Date Job Start Date  \
# 0             NaN  05/10/2022    05/10/2022      05/10/2023     05/10/2022
# 1  NOT APPLICABLE  05/10/2022    05/10/2022      10/01/2022     05/12/2022
# 2  NOT APPLICABLE  05/10/2022    05/10/2022      10/01/2022     05/15/2022
# 3  NOT APPLICABLE  05/10/2022    05/10/2022      10/01/2022     05/15/2022
# 4  NOT APPLICABLE  05/10/2022    05/10/2022      11/15/2022     05/24/2022
#
#   Permittee's First Name Permittee's Last Name Permittee's Business Name  \
# 0                FRANKIE              COLLETTA  FORCE INSTALLATIONS, LLC
# 1                   PAUL                 JOYCE   SUNRUN INSTALLATION SVC
# 2                   PAUL                 JOYCE   SUNRUN INSTALLATION SVC
# 3                   PAUL                 JOYCE   SUNRUN INSTALLATION SVC
# 4              ALEXANDER               YACKERY    VENTURE HOME SOLAR LLC
#
#   Permittee's Phone # Permittee's License Type Permittee's License #  \
# 0        2122441050.0                       GC               0621634
# 1        8055407643.0                       GC               0613329
# 2        8055407643.0                       GC               0613329
# 3        8055407643.0                       GC               0613329
# 4        7183982259.0                       GC               0615255
#
#   Act as Superintendent Permittee's Other Title HIC License  \
# 0                   NaN                     NaN         NaN
# 1                   NaN                     NaN         NaN
# 2                   NaN                     NaN         NaN
# 3                   NaN                     NaN         NaN
# 4                   NaN                     NaN         NaN
#
#   Site Safety Mgr's First Name Site Safety Mgr's Last Name  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   Site Safety Mgr Business Name Superintendent First & Last Name  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#   Superintendent Business Name Owner's Business Type Non-Profit  \
# 0                          NaN           CORPORATION          N
# 1                          NaN            INDIVIDUAL          N
# 2                          NaN            INDIVIDUAL          N
# 3                          NaN            INDIVIDUAL          N
# 4                          NaN            INDIVIDUAL          N
#
#    Owner's Business Name Owner's First Name Owner's Last Name Owner's House #  \
# 0  SL GREEN REALTY CORP.               JOHN             KRUSH             NaN
# 1                    NaN             STEVEN           MONTANA             NaN
# 2                    NaN              SANTO          CEBALLOS             NaN
# 3                    NaN             JOANNA        GIANGRANDE             NaN
# 4                    NaN            ARKADLY           FRIDMAN             NaN
#
#   Owner's House Street Name Owner’s House City Owner’s House State  \
# 0                       NaN                NaN                 NaN
# 1                       NaN                NaN                 NaN
# 2                       NaN                NaN                 NaN
# 3                       NaN                NaN                 NaN
# 4                       NaN                NaN                 NaN
#
#   Owner’s House Zip Code Owner's Phone #           DOBRunDate  PERMIT_SI_NO  \
# 0                    NaN    2125942700.0  05/11/2022 00:00:00     3905851.0
# 1                    NaN    9174201655.0  05/11/2022 00:00:00     3905852.0
# 2                    NaN    7188125847.0  05/11/2022 00:00:00     3905853.0
# 3                    NaN    3478575846.0  05/11/2022 00:00:00     3905854.0
# 4                    NaN    7186195891.0  05/11/2022 00:00:00     3905855.0
#
#     LATITUDE  LONGITUDE  COUNCIL_DISTRICT  CENSUS_TRACT  \
# 0  40.740909 -73.987947               2.0          56.0
# 1  40.563654 -74.179584              51.0       17008.0
# 2  40.639633 -74.094169              49.0          81.0
# 3  40.544597 -74.157153              51.0       15601.0
# 4  40.566798 -74.119726              50.0         134.0
#
#                                      NTA_NAME
# 0  Hudson Yards-Chelsea-Flatiron-Union Square
# 1                               Arden Heights
# 2   West New Brighton-New Brighton-St. George
# 3                                 Great Kills
# 4                      New Dorp-Midland Beach

# %%
# Customize the column names
df.columns = df.columns.str.lower()
df.columns = list(map(lambda x: x.replace(' ', '_'), df.columns))
df.columns
# Out:
# Index(['borough', 'bin_#', 'house_#', 'street_name', 'job_#', 'job_doc._#',
#        'job_type', 'self_cert', 'block', 'lot', 'community_board', 'zip_code',
#        'bldg_type', 'residential', 'special_district_1', 'special_district_2',
#        'work_type', 'permit_status', 'filing_status', 'permit_type',
#        'permit_sequence_#', 'permit_subtype', 'oil_gas', 'site_fill',
#        'filing_date', 'issuance_date', 'expiration_date', 'job_start_date',
#        'permittee's_first_name', 'permittee's_last_name',
#        'permittee's_business_name', 'permittee's_phone_#',
#        'permittee's_license_type', 'permittee's_license_#',
#        'act_as_superintendent', 'permittee's_other_title', 'hic_license',
#        'site_safety_mgr's_first_name', 'site_safety_mgr's_last_name',
#        'site_safety_mgr_business_name', 'superintendent_first_&_last_name',
#        'superintendent_business_name', 'owner's_business_type', 'non-profit',
#        'owner's_business_name', 'owner's_first_name', 'owner's_last_name',
#        'owner's_house_#', 'owner's_house_street_name', 'owner’s_house_city',
#        'owner’s_house_state', 'owner’s_house_zip_code', 'owner's_phone_#',
#        'dobrundate', 'permit_si_no', 'latitude', 'longitude',
#        'council_district', 'census_tract', 'nta_name'],
#       dtype='object')

# %%
# convert the datetime column to a pandas datetime object
df['filing_date'] = pd.to_datetime(df['filing_date'])
df['issuance_date'] = pd.to_datetime(df['issuance_date'])
df['expiration_date'] = pd.to_datetime(df['expiration_date'])
df['job_start_date'] = pd.to_datetime(df['job_start_date'], errors = 'coerce')
df['dobrundate'] = pd.to_datetime(df['dobrundate'])

# %%
# convert the datetime column to an integer
df['filing_date'] = df['filing_date'].values.astype('int64')
df['issuance_date'] = df['issuance_date'].values.astype('int64')
df['expiration_date'] = df['expiration_date'].values.astype('int64')
df['job_start_date'] = df['job_start_date'].values.astype('int64')
df['dobrundate'] = df['dobrundate'].values.astype('int64')

# %%
# divide the resulting integer by the number of nanoseconds in a second
df['filing_date'] = df['filing_date'] // 10**9
df['issuance_date'] = df['issuance_date'] // 10**9
df['expiration_date'] = df['expiration_date'] // 10**9
df['job_start_date'] = df['job_start_date'] // 10**9
df['dobrundate'] = df['dobrundate'] // 10**9

# %%
# col_types = {'borough': 'category', 'bin_#': 'int64', 'house_#': 'string', 'street_name': 'string', 'job_#': 'category', 'job_doc._#': 'string', 'job_type': 'category', 'self_cert': 'bool',
#              'block': 'string', 'lot': '', 'community_board': '', 'zip_code': '',
#              'bldg_type': '', 'residential': '', 'special_district_1': '', 'special_district_2': '', 'work_type': '', 'permit_status': '', 'filing_status': '', 'permit_type': '', 'permit_sequence_#': '',
#              'permit_subtype': '',
#              'oil_gas': '', 'site_fill': '', 'filing_date': '', 'issuance_date': '', 'expiration_date': '', 'job_start_date': '', "permittee's_first_name": '', "permittee's_last_name": '',
#              "permittee's_business_name": '',
#              "permittee's_phone_#": '', "permittee's_license_type": '', "permittee's_license_#": '', 'act_as_superintendent': '', "permittee's_other_title": '', 'hic_license': '',
#              "site_safety_mgr's_first_name": '',
#              "site_safety_mgr's_last_name": '', 'site_safety_mgr_business_name': '', 'superintendent_first_&_last_name': '', 'superintendent_business_name': '', "owner's_business_type": '',
#              'non-profit': '',
#              "owner's_business_name": '', "owner's_first_name": '', "owner's_last_name": '', "owner's_house_#": '', "owner's_house_street_name": '', 'owner’s_house_city': '',
#              'owner’s_house_state': '', 'owner’s_house_zip_code': '',
#              "owner's_phone_#": '', 'dobrundate': '', 'permit_si_no': '', 'latitude': '', 'longitude': '', 'council_district': '', 'census_tract': '', 'nta_name': ''}

# %%
df_debug = df.sample(frac = 0.005, random_state = 434)

# %%
df_debug.shape
# Out:
# (19694, 60)

# %%
df.to_pickle('./Data/Rawdata/df.pkl')
df_debug.to_pickle('./Data/Rawdata/df_debug.pkl')
